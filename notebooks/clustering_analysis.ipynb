# %% [markdown]
# # Customer Personality Analysis - Clustering
#
# This notebook is a reproducible walkthrough of the clustering pipeline. The implementation lives in `src/` so the same analysis can be run from the notebook or from `python src/run_clustering_pipeline.py`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from run_clustering_pipeline import main
print(PROJECT_ROOT)

# %% [markdown]
# ## Run the Full Pipeline
#
# This single call loads the data, preprocesses it, tunes K-Means, AGNES, and DBSCAN, saves figures/tables, and writes the report assets.

# %%
main()

# %% [markdown]
# ## Inspect Final Outputs
#
# The most important deliverables are written to `outputs/tables`, `outputs/figures`, and `report_assets`.

# %%
import pandas as pd

comparison = pd.read_csv(PROJECT_ROOT / 'outputs' / 'tables' / 'clustering_comparison.csv')
comparison

# %%
profiles = pd.read_csv(PROJECT_ROOT / 'outputs' / 'tables' / 'cluster_profiles_best_model.csv')
profiles.head()
